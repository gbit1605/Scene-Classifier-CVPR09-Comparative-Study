# %%
import os
import json
import tensorflow as tf
import tensorflow_hub as hub
import matplotlib.pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %run /content/drive/MyDrive/IndoorSceneClassification/models/architectures.ipynb
# %run /content/drive/MyDrive/IndoorSceneClassification/data/preprocessing.ipynb
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 222, 222, 10)      280
#
#  conv2d_1 (Conv2D)           (None, 220, 220, 10)      910
#
#  max_pooling2d (MaxPooling2D  (None, 110, 110, 10)     0
#  )
#
#  conv2d_3_activations_layer   (None, 108, 108, 10)     910
#  (Conv2D)
#
#  dropout (Dropout)           (None, 108, 108, 10)      0
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 10)       0
#  2D)
#
#  flatten (Flatten)           (None, 29160)             0
#
#  dense (Dense)               (None, 67)                1953787
#
# ...
# Total params: 1,955,887
# Trainable params: 1,955,887
# Non-trainable params: 0
# _________________________________________________________________
# EfficientNetB0_model
# Model: "sequential_1"
# _________________________________________________________________
# ...

# %%
models
# Out:
# {'EfficientNetB0_model': <keras.engine.sequential.Sequential at 0x798502f69990>,
#  'MobileNet_V2_model': <keras.engine.sequential.Sequential at 0x798502f68e20>,
#  'ResNet_V1_model': <keras.engine.sequential.Sequential at 0x798502df0f70>,
#  'Inception_V2_model': <keras.engine.sequential.Sequential at 0x798456fa2dd0>}

# %%
for name, model in models.items():
    print(name)
    model.fit(train,
              epochs=5,
              steps_per_epoch=len(train))
    print('\n %-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-% \n %-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-% \n \n')
    exec(f"{name}.save_weights('/content/drive/MyDrive/IndoorSceneClassification/model_weights/{name}.h5')")
# Out:
# EfficientNetB0_model
# Epoch 1/5
# 168/168 [==============================] - 2612s 15s/step - loss: 4.1649 - accuracy: 0.1851
# Epoch 2/5
# 168/168 [==============================] - 33s 199ms/step - loss: 4.0827 - accuracy: 0.3952
# Epoch 3/5
# 168/168 [==============================] - 34s 204ms/step - loss: 4.0028 - accuracy: 0.4695
# Epoch 4/5
# 168/168 [==============================] - 34s 202ms/step - loss: 3.9248 - accuracy: 0.5066
# Epoch 5/5
# 168/168 [==============================] - 33s 198ms/step - loss: 3.8483 - accuracy: 0.5266
#
#  %-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%
#  %-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%-%
#
#
# MobileNet_V2_model
# Epoch 1/5
# 168/168 [==============================] - 37s 202ms/step - loss: 2.1434 - accuracy: 0.4611
# Epoch 2/5
# 168/168 [==============================] - 35s 205ms/step - loss: 0.8674 - accuracy: 0.7492
# Epoch 3/5
# ...

# %%
custom_cnn_model.fit(train_data_fine_tuning,
                     epochs=5,
                     steps_per_epoch=len(train_data_fine_tuning))
# Out:
# Epoch 1/5
# 168/168 [==============================] - 33s 165ms/step - loss: 11.8962 - accuracy: 0.0162
# Epoch 2/5
# 168/168 [==============================] - 27s 156ms/step - loss: 3.5752 - accuracy: 0.1829
# Epoch 3/5
# 168/168 [==============================] - 27s 155ms/step - loss: 2.4618 - accuracy: 0.4383
# Epoch 4/5
# 168/168 [==============================] - 27s 155ms/step - loss: 1.5990 - accuracy: 0.6432
# Epoch 5/5
# 168/168 [==============================] - 28s 160ms/step - loss: 1.0169 - accuracy: 0.7759

# %%
custom_cnn_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 222, 222, 10)      280
#
#  conv2d_1 (Conv2D)           (None, 220, 220, 10)      910
#
#  max_pooling2d (MaxPooling2D  (None, 110, 110, 10)     0
#  )
#
#  conv2d_3_activations_layer   (None, 108, 108, 10)     910
#  (Conv2D)
#
#  dropout (Dropout)           (None, 108, 108, 10)      0
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 10)       0
#  2D)
#
#  flatten (Flatten)           (None, 29160)             0
#
#  dense (Dense)               (None, 67)                1953787
#
# ...
# Total params: 1,955,887
# Trainable params: 1,955,887
# Non-trainable params: 0
# _________________________________________________________________

# %%
custom_cnn_model.save_weights('/content/drive/MyDrive/IndoorSceneClassification/model_weights/custom_cnn_model.h5')
